# %%
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
import keras.utils.np_utils as ku 
import numpy as np 
import pandas as pd
from nltk import word_tokenize, ngrams
import contractions
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %% [markdown]
# Notes:
#
# Model -
# 2 LSTM (and associated dropout layers)
# achieved 50% accuracy after 100 epochs
#
# Data -
# taylor swift songs truncated to the first 50 songs, represented as variable sized ngrams of sequences from line length in song
#
# Results -
# kinda makes sense, some direct quotes sometimes

# %%
def create_model(predictors, label, max_sequence_len, total_words, num_epochs):
    
    model = Sequential()
    model.add(Embedding(total_words, 32, input_length=max_sequence_len-1))
    model.add(LSTM(150, return_sequences = True))
    model.add(Dropout(0.2))
    model.add(LSTM(100))
    model.add(Dropout(0.2))
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
    earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
    model.fit(predictors, label, epochs=num_epochs, verbose=1, callbacks=[earlystop])
    print(model.summary())
    return model

# %%
def csv_to_lst(file):
    """
    Grabs the lyric section of the given csv and convert it to a string
    Parameters:
        file (CSV): file path where csv is located
    Returns:
        A list string representing all of the text section in the csv
    """
    lyrics_df = pd.read_csv(file) 
#     lyrics_df = lyrics_df

    lyrics_list = list(lyrics_df['lyrics'])


    return lyrics_list
# Out:
# done

# %%
def pre_process_all_lyrics(lyric_list):
    processed = []
    for lyrics in lyric_list:
#         print(lyrics)
        processed.append(pre_process_text(lyrics))
    return processed

# %%
def pre_process_line(line):
    EMBED = 'embed'
    word_list = word_tokenize(line)
    
   
    #index = word_list.index('Lyrics')
    #word_list = word_list[index + 1:]
    
    no_brackets_list = []
    is_inside = False
    punctuation_list = '''!()-[];:'"\,<>./?@#$%^&*_~”“’‘--...``'''''
    
    for word in word_list:
        if word == '[':
            is_inside = True
        if word == ']':
            is_inside = False
        else:
            if not is_inside:
                if word not in punctuation_list:
                    no_brackets_list.append(word.lower())

    if len(no_brackets_list) > 0:
        end_word = no_brackets_list[len(no_brackets_list)-1]   
        if EMBED in end_word:
#             print(end_word)
            embed_location = end_word.index('embed') 
            # all lyric genius data comes with word 'Embed' at the end
            substr = end_word[:embed_location]
            if len(substr) > 0:
                no_brackets_list[len(no_brackets_list)-1] = substr
        
        end_word = no_brackets_list[len(no_brackets_list)-1]  
        new_end_word = ''
        # also sometimes has a number before embed in last word
        for c in end_word:
            if c.isdigit():
                break
            else:
                new_end_word = new_end_word + c
        if len(end_word) > 0:
            no_brackets_list[len(no_brackets_list)-1] = new_end_word
            
    ret = []
    for word in no_brackets_list:
        if len(word) < 0:
            break
        #idk why this is like this 
        elif word == "''":
            break
        else:
            ret.append(word)
    return ret

# %%
def pre_process_text(lyrics):
    """
    Preprocesses the text to add start and end tokens to each sentence
    Parameters:
        lst (list): list of lyrics 
    Returns:
        List of List of words with start and end tokens
    """
    
    lyrics = contractions.fix(lyrics)
#     print(lyrics)
    line_list = lyrics.split("\n")
    line_list = line_list[1:]
    
    ret = []
    for line in line_list:
        if not len(line) == 0:
            to_be_appended = pre_process_line(line)
            if len(to_be_appended) > 0:
                ret.append(to_be_appended)
    return ret

# %%
def dataset_preparation(data):

    # basic cleanup
#     corpus = data.lower().split("\n")
    # tokenization	
    corpus = flatten_lines(data)
    print(corpus[:10])
    tokenizer.fit_on_texts(corpus)
    total_words = len(tokenizer.word_index) + 1

    print('tokenization:')
    print(tokenizer.word_index)
    # create input sequences using list of tokens
    input_sequences = []
    for line in corpus:
        token_list = tokenizer.texts_to_sequences([line])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)

    print('input_sequences:')
    print(input_sequences)
    # pad sequences 
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

    print('padded input_sequences:')
    print(input_sequences)
    # create predictors and label
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    
    print('X predictors:')
    print(predictors)
    print('y labels:')
    print(label)
    label = ku.to_categorical(label, num_classes=total_words)
    
    return predictors, label, max_sequence_len, total_words

# %%
def flatten_lines(data):
    corpus = []
    for song in data:
        for line in song:
            line_string = ""
            for word in line: 
                line_string = line_string + " " + word
            corpus.append(line_string)
    return corpus

# %%
lst = csv_to_lst('taylorswift.csv')
data = pre_process_all_lyrics(lst)[:50]
# print(data)

# %%
# for song in data:
#     for line in song:
#         print(line)

# %%
predictors, label, max_sequence_len, total_words = dataset_preparation(data)
# Out:
# [' i walked through the door with you the air was cold', " but something 'bout it felt like home somehow", " and i left my scarf there at your sister 's house", ' and you have still got it in your drawer even now', ' oh your sweet disposition and my wide-eyed gaze', ' we are singin in the car getting lost upstate', ' autumn leaves fallin down like pieces into place', ' and i can picture it after all these days', ' and i know it is long gone and', " that magic 's not here no more"]
# tokenization:
# {'i': 1, 'you': 2, 'the': 3, 'it': 4, 'and': 5, 'me': 6, 'to': 7, 'my': 8, 'a': 9, 'is': 10, 'not': 11, 'in': 12, 'was': 13, 'your': 14, 'of': 15, 'all': 16, 'there': 17, 'do': 18, 'that': 19, 'like': 20, 'but': 21, 'we': 22, 'oh': 23, 'what': 24, 'be': 25, 'am': 26, 'are': 27, 'just': 28, 'want': 29, 'so': 30, 'on': 31, 'for': 32, 'have': 33, 'know': 34, 'never': 35, 'would': 36, 'because': 37, 'can': 38, 'will': 39, 'this': 40, 'when': 41, 'ooh': 42, 'made': 43, 'with': 44, 'time': 45, 'look': 46, 'remember': 47, 'if': 48, 'too': 49, 'out': 50, 'up': 51, 'got': 52, 'at': 53, 'now': 54, 'love': 55, 'were': 56, 'well': 57, 'down': 58, 'call': 59, 'they': 60, 'did': 61, 'one': 62, 'no': 63, 'could': 64, 'yeah': 65, "'s": 66, 'go': 67, 'baby': 68, 'say': 69, 'he': 70, 'take': 71, 'see': 72, 'back': 73, 'been': 74, 'think': 75, 'ah': 76, 'di': 77, 'said': 78, 'from': 79, 'again': 80, 'us': 81, 'end': 82, 'game': 83, 'about': 84, 'bad': 85, 'night': 86, 'good': 87, 'thing': 88, 'ever': 89, 'first': 90, 'long': 91, 'come': 92, 'get': 93, 'she': 94, 'right': 95, 'man': 96, 'home': 97, 'had': 98, 'then': 99, 'only': 100, 'tell': 101, 'car': 102, 'knew': 103, 'every': 104, 'gave': 105, 'things': 106, 'hair': 107, 'as': 108, '
#  [  0   0   0 ...   2   5   8]]
# y labels:
# [291 146   3 ...   5   8 623]

# %%
print('predictors: ', len(predictors))
# print(predictors[:3])
print('labels: ', label.shape)
# print(label[:3])
print('max sequence len: ', max_sequence_len)
print('total words: ', total_words)
# Out:
# predictors:  19137
# labels:  (19137, 2090)
# max sequence len:  19
# total words:  2090

# %%
model = create_model(predictors, label, max_sequence_len, total_words, 100)
# Out:
# Epoch 1/100
# 597/599 [============================>.] - ETA: 0s - loss: 5.9779 - accuracy: 0.0431WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 19s 26ms/step - loss: 5.9772 - accuracy: 0.0432
# Epoch 2/100
# 598/599 [============================>.] - ETA: 0s - loss: 5.6077 - accuracy: 0.0456WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 5.6076 - accuracy: 0.0456
# Epoch 3/100
# 599/599 [==============================] - ETA: 0s - loss: 5.4062 - accuracy: 0.0578WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 5.4062 - accuracy: 0.0578
# Epoch 4/100
# 598/599 [============================>.] - ETA: 0s - loss: 5.2048 - accuracy: 0.0782WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 5.2047 - accuracy: 0.0782
# Epoch 5/100
# 598/599 [============================>.] - ETA: 0s - loss: 5.0170 - accuracy: 0.0940WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 5.0169 - accuracy: 0.0940
# Epoch 6/100
# 598/599 [============================>.] - ETA: 0s - loss: 4.8362 - accuracy: 0.1113WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 4.8360 - accuracy: 0.1114
# Epoch 7/100
# 598/599 [============================>.] - ETA: 0s - loss: 4.6701 - accuracy: 0.1349WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 4.6702 - accuracy: 0.1349
# Epoch 8/100
# 598/599 [============================>.] - ETA: 0s - loss: 4.5206 - accuracy: 0.1493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 4.5204 - accuracy: 0.1493
# Epoch 9/100
# 597/599 [============================>.] - ETA: 0s - loss: 4.3834 - accuracy: 0.1625WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 4.3830 - accuracy: 0.1626
# Epoch 10/100
# 597/599 [============================>.] - ETA: 0s - loss: 4.2490 - accuracy: 0.1777WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 4.2487 - accuracy: 0.1777
# Epoch 11/100
# 597/599 [============================>.] - ETA: 0s - loss: 4.1387 - accuracy: 0.1877WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 4.1371 - accuracy: 0.1878
# Epoch 12/100
# 598/599 [============================>.] - ETA: 0s - loss: 4.0212 - accuracy: 0.2001WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 4.0214 - accuracy: 0.2001
# Epoch 13/100
# 598/599 [============================>.] - ETA: 0s - loss: 3.9121 - accuracy: 0.2088WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 3.9121 - accuracy: 0.2088
# Epoch 14/100
# 597/599 [============================>.] - ETA: 0s - loss: 3.8175 - accuracy: 0.2196WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 3.8179 - accuracy: 0.2197
# Epoch 15/100
# 598/599 [============================>.] - ETA: 0s - loss: 3.7235 - accuracy: 0.2298WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.7235 - accuracy: 0.2298
# Epoch 16/100
# 598/599 [============================>.] - ETA: 0s - loss: 3.6361 - accuracy: 0.2408WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.6363 - accuracy: 0.2407
# Epoch 17/100
# 598/599 [============================>.] - ETA: 0s - loss: 3.5628 - accuracy: 0.2516WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.5627 - accuracy: 0.2516
# Epoch 18/100
# 597/599 [============================>.] - ETA: 0s - loss: 3.4784 - accuracy: 0.2599WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.4783 - accuracy: 0.2601
# Epoch 19/100
# 597/599 [============================>.] - ETA: 0s - loss: 3.4042 - accuracy: 0.2689WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.4040 - accuracy: 0.2690
# Epoch 20/100
# 597/599 [============================>.] - ETA: 0s - loss: 3.3450 - accuracy: 0.2756WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.3450 - accuracy: 0.2755
# Epoch 21/100
# 598/599 [============================>.] - ETA: 0s - loss: 3.2737 - accuracy: 0.2832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.2737 - accuracy: 0.2833
# Epoch 22/100
# 599/599 [==============================] - ETA: 0s - loss: 3.2281 - accuracy: 0.2888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.2281 - accuracy: 0.2888
# Epoch 23/100
# 597/599 [============================>.] - ETA: 0s - loss: 3.1679 - accuracy: 0.2964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.1674 - accuracy: 0.2967
# Epoch 24/100
# 598/599 [============================>.] - ETA: 0s - loss: 3.1236 - accuracy: 0.3096WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.1235 - accuracy: 0.3097
# Epoch 25/100
# 597/599 [============================>.] - ETA: 0s - loss: 3.0717 - accuracy: 0.3133WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.0713 - accuracy: 0.3133
# Epoch 26/100
# 598/599 [============================>.] - ETA: 0s - loss: 3.0241 - accuracy: 0.3202WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 17s 28ms/step - loss: 3.0240 - accuracy: 0.3203
# Epoch 27/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.9785 - accuracy: 0.3266WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 14s 23ms/step - loss: 2.9796 - accuracy: 0.3265
# Epoch 28/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.9416 - accuracy: 0.3371WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 14s 24ms/step - loss: 2.9415 - accuracy: 0.3371
# Epoch 29/100
# 599/599 [==============================] - ETA: 0s - loss: 2.9031 - accuracy: 0.3401WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 15s 25ms/step - loss: 2.9031 - accuracy: 0.3401
# Epoch 30/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.8767 - accuracy: 0.3469WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.8768 - accuracy: 0.3469
# Epoch 31/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.8297 - accuracy: 0.3545WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.8299 - accuracy: 0.3544
# Epoch 32/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.7966 - accuracy: 0.3587WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.7966 - accuracy: 0.3587
# Epoch 33/100
# 599/599 [==============================] - ETA: 0s - loss: 2.7577 - accuracy: 0.3659WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.7577 - accuracy: 0.3659
# Epoch 34/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.7362 - accuracy: 0.3730WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.7362 - accuracy: 0.3730
# Epoch 35/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.6960 - accuracy: 0.3809WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.6959 - accuracy: 0.3808
# Epoch 36/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.6608 - accuracy: 0.3859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.6607 - accuracy: 0.3859
# Epoch 37/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.6317 - accuracy: 0.3860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.6320 - accuracy: 0.3861
# Epoch 38/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.6040 - accuracy: 0.3968WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.6042 - accuracy: 0.3968
# Epoch 39/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.5785 - accuracy: 0.3979WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.5784 - accuracy: 0.3978
# Epoch 40/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.5419 - accuracy: 0.4091WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.5420 - accuracy: 0.4091
# Epoch 41/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.5228 - accuracy: 0.4123WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.5227 - accuracy: 0.4122
# Epoch 42/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.4927 - accuracy: 0.4194WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.4926 - accuracy: 0.4194
# Epoch 43/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.4703 - accuracy: 0.4236WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.4701 - accuracy: 0.4237
# Epoch 44/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.4489 - accuracy: 0.4232WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.4488 - accuracy: 0.4233
# Epoch 45/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.4298 - accuracy: 0.4286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.4297 - accuracy: 0.4286
# Epoch 46/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.4058 - accuracy: 0.4328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.4069 - accuracy: 0.4328
# Epoch 47/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.3695 - accuracy: 0.4400WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.3694 - accuracy: 0.4400
# Epoch 48/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.3516 - accuracy: 0.4427WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.3521 - accuracy: 0.4426
# Epoch 49/100
# 599/599 [==============================] - ETA: 0s - loss: 2.3341 - accuracy: 0.4487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.3341 - accuracy: 0.4487
# Epoch 50/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.3147 - accuracy: 0.4543WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.3149 - accuracy: 0.4543
# Epoch 51/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.2931 - accuracy: 0.4542WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.2932 - accuracy: 0.4541
# Epoch 52/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.2708 - accuracy: 0.4582WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.2710 - accuracy: 0.4582
# Epoch 53/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.2656 - accuracy: 0.4587WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 15s 25ms/step - loss: 2.2653 - accuracy: 0.4588
# Epoch 54/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.2393 - accuracy: 0.4642WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 15s 26ms/step - loss: 2.2396 - accuracy: 0.4642
# Epoch 55/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.2186 - accuracy: 0.4685WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 15s 26ms/step - loss: 2.2186 - accuracy: 0.4685
# Epoch 56/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.2069 - accuracy: 0.4713WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.2069 - accuracy: 0.4713
# Epoch 57/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.1893 - accuracy: 0.4782WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 15s 26ms/step - loss: 2.1892 - accuracy: 0.4782
# Epoch 58/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.1802 - accuracy: 0.4727WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.1801 - accuracy: 0.4727
# Epoch 59/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.1491 - accuracy: 0.4834WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.1486 - accuracy: 0.4834
# Epoch 60/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.1553 - accuracy: 0.4788WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.1552 - accuracy: 0.4788
# Epoch 61/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.1209 - accuracy: 0.4882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.1217 - accuracy: 0.4880
# Epoch 62/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.1070 - accuracy: 0.4881WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.1075 - accuracy: 0.4880
# Epoch 63/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.0875 - accuracy: 0.4950WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.0868 - accuracy: 0.4952
# Epoch 64/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.0787 - accuracy: 0.4958WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.0788 - accuracy: 0.4957
# Epoch 65/100
# 598/599 [============================>.] - ETA: 0s - loss: 2.0704 - accuracy: 0.4985WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.0704 - accuracy: 0.4985
# Epoch 66/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.0497 - accuracy: 0.5011WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.0492 - accuracy: 0.5014
# Epoch 67/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.0370 - accuracy: 0.5069WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 2.0369 - accuracy: 0.5070
# Epoch 68/100
# 597/599 [============================>.] - ETA: 0s - loss: 2.0287 - accuracy: 0.5031WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 2.0300 - accuracy: 0.5029
# Epoch 69/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.9980 - accuracy: 0.5129WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.9984 - accuracy: 0.5130
# Epoch 70/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.9965 - accuracy: 0.5122WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.9965 - accuracy: 0.5122
# Epoch 71/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.9785 - accuracy: 0.5209WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.9790 - accuracy: 0.5208
# Epoch 72/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.9728 - accuracy: 0.5176WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.9728 - accuracy: 0.5176
# Epoch 73/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.9512 - accuracy: 0.5204WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.9512 - accuracy: 0.5206
# Epoch 74/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.9461 - accuracy: 0.5241WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.9464 - accuracy: 0.5238
# Epoch 75/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.9330 - accuracy: 0.5221WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.9326 - accuracy: 0.5222
# Epoch 76/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.9261 - accuracy: 0.5233WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.9257 - accuracy: 0.5236
# Epoch 77/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.9155 - accuracy: 0.5317WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.9156 - accuracy: 0.5316
# Epoch 78/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.8958 - accuracy: 0.5321WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.8958 - accuracy: 0.5321
# Epoch 79/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.8909 - accuracy: 0.5334WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.8911 - accuracy: 0.5334
# Epoch 80/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.8701 - accuracy: 0.5358WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 15s 26ms/step - loss: 1.8703 - accuracy: 0.5358
# Epoch 81/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.8656 - accuracy: 0.5362WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 15s 26ms/step - loss: 1.8647 - accuracy: 0.5363
# Epoch 82/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.8540 - accuracy: 0.5433WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.8542 - accuracy: 0.5433
# Epoch 83/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.8442 - accuracy: 0.5435WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.8442 - accuracy: 0.5434
# Epoch 84/100
# 599/599 [==============================] - ETA: 0s - loss: 1.8348 - accuracy: 0.5480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.8348 - accuracy: 0.5480
# Epoch 85/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.8243 - accuracy: 0.5455WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.8236 - accuracy: 0.5459
# Epoch 86/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.8054 - accuracy: 0.5503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.8059 - accuracy: 0.5502
# Epoch 87/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.8066 - accuracy: 0.5494WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.8066 - accuracy: 0.5495
# Epoch 88/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.7961 - accuracy: 0.5540WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.7967 - accuracy: 0.5538
# Epoch 89/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.7824 - accuracy: 0.5540WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.7824 - accuracy: 0.5541
# Epoch 90/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.7715 - accuracy: 0.5567WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.7716 - accuracy: 0.5567
# Epoch 91/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.7640 - accuracy: 0.5552WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.7640 - accuracy: 0.5553
# Epoch 92/100
# 599/599 [==============================] - ETA: 0s - loss: 1.7600 - accuracy: 0.5623WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.7600 - accuracy: 0.5623
# Epoch 93/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.7465 - accuracy: 0.5622WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.7459 - accuracy: 0.5622
# Epoch 94/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.7344 - accuracy: 0.5642WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.7344 - accuracy: 0.5642
# Epoch 95/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.7289 - accuracy: 0.5685WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.7289 - accuracy: 0.5685
# Epoch 96/100
# 598/599 [============================>.] - ETA: 0s - loss: 1.7103 - accuracy: 0.5719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.7104 - accuracy: 0.5719
# Epoch 97/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.7100 - accuracy: 0.5694WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.7097 - accuracy: 0.5694
# Epoch 98/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.6991 - accuracy: 0.5726WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.6989 - accuracy: 0.5729
# Epoch 99/100
# 597/599 [============================>.] - ETA: 0s - loss: 1.6906 - accuracy: 0.5749WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 27ms/step - loss: 1.6906 - accuracy: 0.5749
# Epoch 100/100
# 599/599 [==============================] - ETA: 0s - loss: 1.6781 - accuracy: 0.5756WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy
# 599/599 [==============================] - 16s 26ms/step - loss: 1.6781 - accuracy: 0.5756
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 18, 32)            66880
#
#  lstm_6 (LSTM)               (None, 18, 150)           109800
#
#  dropout_3 (Dropout)         (None, 18, 150)           0
#
#  lstm_7 (LSTM)               (None, 100)               100400
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 2090)              211090
#
# =================================================================
# Total params: 488,170
# Trainable params: 488,170
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def generate_text(tokenizer, seed_text, next_words, max_sequence_len):
#     lines = []
    LINE_LEN = np.random.randint(1, max_sequence_len)
    words = []
    words.extend(seed_text.split())
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
#         print('-----')
#         print(predicted.shape)
#         choice = np.argmax(predicted)
        choice = np.random.choice(len(predicted[0]), p=predicted[0])
#         choice = sample(predicted[0])
#         print('choice: ', choice)
#         print(index_of)
        word = tokenizer.index_word[choice]
        words.append(word)
#         print('word: ', word)
        if (len(words) % LINE_LEN == 0): # new line time
#             print(words)
#             print(len(words))
            words.append('\n')
            seed_text = word
        else:
            seed_text = seed_text + " " + word
#         seed_text = word
#         output_word = ""
#         for word, index in tokenizer.word_index.items():
#             if index == predicted[0]:
#                 output_word = word
#                 break
#         seed_text += " " + output_word
    return format_lyrics(words)

# %%
def sample(preds, temperature=1):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def format_lyrics(words):
    lyr = ""
    for word in words:
        lyr = lyr + " " + word
    return lyr

# %%
generated = generate_text(tokenizer, "you", 50, max_sequence_len)
print(generated)
# Out:
#  you should take the ground running each away with me now i am mad
#  into me trying to i ever work and the ballet then i owe
#  all the heart is folklore from some weight of you it was like
#  they say i do not like the ending to a my

# %%
generated2 = generate_text(tokenizer, "i", 50, max_sequence_len)
print(generated2)
# Out:
#  i would swing for to
#  be certain i go
#  pérignon i just made
#  me want to take
#  the eagles year down
#  the stairs i was
#  that it is a
#  string 's actin now
#  he have got problems
#  on the car keys
#  pérignon you would have
#  i sneak again i
#  want to

# %%
generated3 = generate_text(tokenizer, "this is", 50, max_sequence_len)
print(generated3)
# Out:
#  this is our
#  album on
#  the pool
#  that is
#  not it
#  was rare
#  i was
#  my man
#  i never
#  did not
#  weeping in
#  your wildest
#  rumors 's
#  have why
#  is at
#  the flickers
#  the really
#  precedes me
#  like a
#  million little
#  letters that
#  i can
#  i think
#  about the
#  ties were
#  dare

# %%
generated4 = generate_text(tokenizer, "his", 50, max_sequence_len)
print(generated4)
# Out:
#  his leaves falling down oh persona at friends i heard you say
#  then canceled my breaks loose good if the clothes was the
#  more that i had that all now i had you over
#  the stairs i was there i was there i was there
#  is daughter of this guitar big

# %%
generated5 = generate_text(tokenizer, "my", 50, max_sequence_len)
print(generated5)
# Out:
#  my hands are shaking down in my name you oh
#  lord save me i am a crumpled when i
#  remember it all too well yeah i would go
#  floor on my sweatshirt down around saving take my
#  tlc was quite od id my day times you
#  are not my type you

# %% [markdown]
# # Sources
#
# ## Dataset
# ## Text Preprocessing
# ## Word2Vec Visualizations
# ## Model Creation
# ## Text Generation
